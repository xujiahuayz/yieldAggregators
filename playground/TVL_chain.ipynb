# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("all.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/jiahuaxu/GitHub/yieldAggregators/playground/TVL_chain.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/jiahuaxu/GitHub/yieldAggregators/playground/TVL_chain.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv("all.csv")
#
# File ~/GitHub/yieldAggregators/venv/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/GitHub/yieldAggregators/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/GitHub/yieldAggregators/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/GitHub/yieldAggregators/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:934, in TextFileReader.__init__(self, f, engine, **kwds)
#     931     self.options["has_index_names"] = kwds["has_index_names"]
#     933 self.handles: IOHandles | None = None
# --> 934 self._engine = self._make_engine(f, self.engine)
#
# File ~/GitHub/yieldAggregators/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1218, in TextFileReader._make_engine(self, f, engine)
#    1214     mode = "rb"
#    1215 # error: No overload variant of "get_handle" matches argument types
#    1216 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1217 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1218 self.handles = get_handle(  # type: ignore[call-overload]
#    1219     f,
#    1220     mode,
#    1221     encoding=self.options.get("encoding", None),
#    1222     compression=self.options.get("compression", None),
#    1223     memory_map=self.options.get("memory_map", False),
#    1224     is_text=is_text,
#    1225     errors=self.options.get("encoding_errors", "strict"),
#    1226     storage_options=self.options.get("storage_options", None),
#    1227 )
#    1228 assert self.handles is not None
#    1229 f = self.handles.handle
#
# File ~/GitHub/yieldAggregators/venv/lib/python3.10/site-packages/pandas/io/common.py:786, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     781 elif isinstance(handle, str):
#     782     # Check whether the filename is to be opened in binary mode.
#     783     # Binary mode does not support 'encoding' and 'newline'.
#     784     if ioargs.encoding and "b" not in ioargs.mode:
#     785         # Encoding
# --> 786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#     789             encoding=ioargs.encoding,
#     790             errors=errors,
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
#     795         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'all.csv'

# %%
df
# Out:
#        Unnamed: 0 Category     Chain   Category.1  \
# 0            Date      NaN       NaN          NaN
# 1       Timestamp      NaN       NaN          NaN
# 2            WBTC   Bridge  ethereum          TVL
# 3            WBTC   Bridge     Total          TVL
# 4            WBTC   Bridge  ethereum  Tokens(USD)
# ...           ...      ...       ...          ...
# 232825  SushiSwap    Dexes    fantom       Tokens
# 232826  SushiSwap    Dexes    fantom       Tokens
# 232827  SushiSwap    Dexes    fantom       Tokens
# 232828  SushiSwap    Dexes    fantom       Tokens
# 232829  SushiSwap    Dexes   staking       Tokens
#
#                                                     Token  Unnamed: 5  \
# 0                                                     NaN  03/11/2018
# 1                                                     NaN  1541203200
# 2                                                     NaN         NaN
# 3                                                     NaN         NaN
# 4                                                    WBTC         NaN
# ...                                                   ...         ...
# 232825  UNKNOWN (fantom:0xbc0071caa8d58a85c9bacbd27bb2...         NaN
# 232826  UNKNOWN (fantom:0xb70130610e19f93e7e775f130eb7...         NaN
# 232827  UNKNOWN (fantom:0x47b820f651eba16016ae5ee1a97a...         NaN
# 232828                                               WBAN         NaN
# 232829                                              SUSHI         NaN
#
#         Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0       04/11/2018  05/11/2018  06/11/2018  07/11/2018  ...
# 1       1541289600  1541376000  1541462400  1541548800  ...
# 2              NaN         NaN         NaN         NaN  ...
# 3              NaN         NaN         NaN         NaN  ...
# 4              NaN         NaN         NaN         NaN  ...
# ...            ...         ...         ...         ...  ...
# 232825         NaN         NaN         NaN         NaN  ...
# 232826         NaN         NaN         NaN         NaN  ...
# 232827         NaN         NaN         NaN         NaN  ...
# 232828         NaN         NaN         NaN         NaN  ...
# 232829         NaN         NaN         NaN         NaN  ...
#
#             Unnamed: 1400      Unnamed: 1401     Unnamed: 1402  \
# 0              29/08/2022         30/08/2022        31/08/2022
# 1              1661731200         1661817600        1661904000
# 2       4869593226.691961  5000890640.004321  4937237319.11634
# 3       4869593226.691961  5000890640.004321  4937237319.11634
# 4       4869593226.691961  5000890640.004321  4937237319.11634
# ...                   ...                ...               ...
# 232825                NaN                NaN               NaN
# 232826                NaN                NaN               NaN
# 232827                NaN                NaN               NaN
# 232828                NaN                NaN               NaN
# 232829        6.89879e+07         6.5351e+07       6.50057e+07
#
#            Unnamed: 1403      Unnamed: 1404      Unnamed: 1405  \
# 0             01/09/2022         02/09/2022         03/09/2022
# 1             1661990400         1662076800         1662163200
# 2       4941860938.24231  4965586784.324018  4975311555.955182
# 3       4941860938.24231  4965586784.324018  4975311555.955182
# 4       4941860938.24231  4965586784.324018  4975311555.955182
# ...                  ...                ...                ...
# 232825               NaN                NaN                NaN
# 232826               NaN                NaN                NaN
# 232827               NaN                NaN                NaN
# 232828               NaN                NaN                NaN
# 232829       6.50318e+07        6.50072e+07        6.49751e+07
#
#             Unnamed: 1406      Unnamed: 1407      Unnamed: 1408  \
# 0              04/09/2022         05/09/2022         06/09/2022
# 1              1662249600         1662336000         1662422400
# 2       4918092373.565338  4937415873.667784  4986965662.266166
# 3       4918092373.565338  4937415873.667784  4986965662.266166
# 4       4918092373.565338  4937415873.667784  4986965662.266166
# ...                   ...                ...                ...
# 232825                NaN                NaN                NaN
# 232826                NaN                NaN                NaN
# 232827                NaN                NaN                NaN
# 232828                NaN                NaN                NaN
# 232829        6.49537e+07        6.52245e+07        6.52274e+07
#
#             Unnamed: 1409
# 0              07/09/2022
# 1              1662508800
# 2       4677117851.318911
# 3       4677117851.318911
# 4       4677117851.318911
# ...                   ...
# 232825                NaN
# 232826                NaN
# 232827                NaN
# 232828                NaN
# 232829        6.51452e+07
#
# [232830 rows x 1410 columns]

# %%
df['Category'].unique()
# Out:
# array([nan, 'Bridge', 'Yield Aggregator', 'Dexes', 'Options',
#        'Derivatives', 'Cross Chain', 'CDP', 'Services', 'Lending',
#        'Payments', 'Privacy', 'Insurance', 'Staking', 'Yield',
#        'Synthetics', 'RWA', 'Algo-Stables', 'Indexes', 'Liquid Staking',
#        'Farm', 'Chain', 'Reserve Currency', 'Launchpad', 'Oracle',
#        'Prediction Market', 'NFT Marketplace', 'NFT Lending', 'Gaming'],
#       dtype=object)

# %%
df_YA = df[df['Category'] == "Yield Aggregator"]

# %%
df_YA
# Out:
#              Unnamed: 0          Category     Chain   Category.1       Token  \
# 8       Harvest Finance  Yield Aggregator       bsc          TVL         NaN
# 9       Harvest Finance  Yield Aggregator  ethereum          TVL         NaN
# 10      Harvest Finance  Yield Aggregator   polygon          TVL         NaN
# 11      Harvest Finance  Yield Aggregator     Total          TVL         NaN
# 12      Harvest Finance  Yield Aggregator       bsc  Tokens(USD)      tether
# ...                 ...               ...       ...          ...         ...
# 170056          Solidex  Yield Aggregator    fantom       Tokens   3POOLV2-F
# 170057          Solidex  Yield Aggregator    fantom       Tokens      LNWFTM
# 170058          Solidex  Yield Aggregator    fantom       Tokens     RENUSDC
# 170059          Solidex  Yield Aggregator    fantom       Tokens      LAMBDA
# 170060          Solidex  Yield Aggregator    fantom       Tokens  RAINSPIRIT
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 8             NaN        NaN        NaN        NaN        NaN  ...
# 9             NaN        NaN        NaN        NaN        NaN  ...
# 10            NaN        NaN        NaN        NaN        NaN  ...
# 11            NaN        NaN        NaN        NaN        NaN  ...
# 12            NaN        NaN        NaN        NaN        NaN  ...
# ...           ...        ...        ...        ...        ...  ...
# 170056        NaN        NaN        NaN        NaN        NaN  ...
# 170057        NaN        NaN        NaN        NaN        NaN  ...
# 170058        NaN        NaN        NaN        NaN        NaN  ...
# 170059        NaN        NaN        NaN        NaN        NaN  ...
# 170060        NaN        NaN        NaN        NaN        NaN  ...
#
#              Unnamed: 1400       Unnamed: 1401       Unnamed: 1402  \
# 8       255255.05162545433  258858.80928489455   261699.5677500801
# 9       27248255.927962773  27420868.072507273  27541558.398812864
# 10      1176519.1837879864  1210819.3985969776  1229498.4262738328
# 11      28680030.163376212  28890546.280389145   29032756.39283678
# 12      255255.05162545433  258858.80928489455   261699.5677500801
# ...                    ...                 ...                 ...
# 170056                   1                   1                   1
# 170057                 NaN                 NaN                 NaN
# 170058                 NaN                 NaN                 NaN
# 170059                 NaN                 NaN                 NaN
# 170060         1.05652e+06         1.06974e+06          1.0784e+06
#
#              Unnamed: 1403       Unnamed: 1404       Unnamed: 1405  \
# 8       261287.91433000923   261699.5677500801  261961.26731783015
# 9        27498235.52745153  27541558.398812864  27569099.957211673
# 10       1227564.425249304  1229498.4262738328  1230727.9247001065
# 11      28987087.867030844   29032756.39283678  29061789.149229612
# 12      261287.91433000923   261699.5677500801  261961.26731783015
# ...                    ...                 ...                 ...
# 170056                   1                   1                   1
# 170057                 NaN                 NaN                 NaN
# 170058                 NaN                 NaN                 NaN
# 170059                 NaN                 NaN                 NaN
# 170060         1.08468e+06          1.1556e+06         1.16554e+06
#
#              Unnamed: 1406       Unnamed: 1407       Unnamed: 1408  \
# 8       261961.26731783015  261961.26731783015  261961.26731783015
# 9       27569099.957211673  27569099.957211673  27569099.957211673
# 10      1230727.9247001065  1230727.9247001065  1230727.9247001065
# 11      29061789.149229612  29061789.149229612   29061789.14922961
# 12      261961.26731783015  261961.26731783015  261961.26731783015
# ...                    ...                 ...                 ...
# 170056                   1                   1                   1
# 170057                 NaN                 NaN                 NaN
# 170058                 NaN                 NaN                 NaN
# 170059                 NaN                 NaN                 NaN
# 170060         1.14489e+06         1.15942e+06         1.21703e+06
#
#              Unnamed: 1409
# 8       249926.33134098107
# 9        26717282.21885312
# 10      1125065.1671445884
# 11       28092273.71733869
# 12      249926.33134098107
# ...                    ...
# 170056                   1
# 170057                 NaN
# 170058                 NaN
# 170059                 NaN
# 170060         1.21264e+06
#
# [6363 rows x 1410 columns]

# %%
df_YA['Category.1'].unique()
# Out:
# array(['TVL', 'Tokens(USD)', 'Tokens'], dtype=object)

# %%
df_YA_TVL = df_YA[df_YA['Category.1'] == "TVL"]

# %%
df_YA_TVL
# Out:
#              Unnamed: 0          Category           Chain Category.1 Token  \
# 8       Harvest Finance  Yield Aggregator             bsc        TVL   NaN
# 9       Harvest Finance  Yield Aggregator        ethereum        TVL   NaN
# 10      Harvest Finance  Yield Aggregator         polygon        TVL   NaN
# 11      Harvest Finance  Yield Aggregator           Total        TVL   NaN
# 32        Yearn Finance  Yield Aggregator        ethereum        TVL   NaN
# ...                 ...               ...             ...        ...   ...
# 119604         AutoBark  Yield Aggregator           Total        TVL   NaN
# 168673          Solidex  Yield Aggregator  fantom-staking        TVL   NaN
# 168674          Solidex  Yield Aggregator           Total        TVL   NaN
# 168675          Solidex  Yield Aggregator         staking        TVL   NaN
# 168676          Solidex  Yield Aggregator          fantom        TVL   NaN
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 8             NaN        NaN        NaN        NaN        NaN  ...
# 9             NaN        NaN        NaN        NaN        NaN  ...
# 10            NaN        NaN        NaN        NaN        NaN  ...
# 11            NaN        NaN        NaN        NaN        NaN  ...
# 32            NaN        NaN        NaN        NaN        NaN  ...
# ...           ...        ...        ...        ...        ...  ...
# 119604        NaN        NaN        NaN        NaN        NaN  ...
# 168673        NaN        NaN        NaN        NaN        NaN  ...
# 168674        NaN        NaN        NaN        NaN        NaN  ...
# 168675        NaN        NaN        NaN        NaN        NaN  ...
# 168676        NaN        NaN        NaN        NaN        NaN  ...
#
#              Unnamed: 1400       Unnamed: 1401       Unnamed: 1402  \
# 8       255255.05162545433  258858.80928489455   261699.5677500801
# 9       27248255.927962773  27420868.072507273  27541558.398812864
# 10      1176519.1837879864  1210819.3985969776  1229498.4262738328
# 11      28680030.163376212  28890546.280389145   29032756.39283678
# 32      473995846.61347914   490525601.9303609    485757465.321124
# ...                    ...                 ...                 ...
# 119604              113564              117229              317544
# 168673         9.29086e+06         9.29947e+06         9.63584e+06
# 168674         6.76605e+06         6.86577e+06         6.80814e+06
# 168675         9.29086e+06         9.29947e+06         9.63584e+06
# 168676         6.76605e+06         6.86577e+06         6.80814e+06
#
#              Unnamed: 1403       Unnamed: 1404       Unnamed: 1405  \
# 8       261287.91433000923   261699.5677500801  261961.26731783015
# 9        27498235.52745153  27541558.398812864  27569099.957211673
# 10       1227564.425249304  1229498.4262738328  1230727.9247001065
# 11      28987087.867030844   29032756.39283678  29061789.149229612
# 32      489102528.70126253      492150277.0516    492687664.254863
# ...                    ...                 ...                 ...
# 119604              317268              318560              318479
# 168673         1.17272e+07         9.56539e+06         1.21059e+07
# 168674         6.98058e+06         6.69244e+06         6.83449e+06
# 168675         1.17272e+07         9.56539e+06         1.21059e+07
# 168676         6.98058e+06         6.69244e+06         6.83449e+06
#
#              Unnamed: 1406       Unnamed: 1407       Unnamed: 1408  \
# 8       261961.26731783015  261961.26731783015  261961.26731783015
# 9       27569099.957211673  27569099.957211673  27569099.957211673
# 10      1230727.9247001065  1230727.9247001065  1230727.9247001065
# 11      29061789.149229612  29061789.149229612   29061789.14922961
# 32      487695244.63051987  490575730.57805204   495329900.0304985
# ...                    ...                 ...                 ...
# 119604              319848              319246              322139
# 168673         1.34727e+07         1.22589e+07         1.63051e+07
# 168674         6.74487e+06         6.75297e+06         7.09646e+06
# 168675         1.34727e+07         1.22589e+07         1.63051e+07
# 168676         6.74487e+06         6.75297e+06         7.09646e+06
#
#              Unnamed: 1409
# 8       249926.33134098107
# 9        26717282.21885312
# 10      1125065.1671445884
# 11       28092273.71733869
# 32       477277229.4721298
# ...                    ...
# 119604              316687
# 168673         1.51314e+07
# 168674         6.88228e+06
# 168675         1.51314e+07
# 168676         6.88228e+06
#
# [361 rows x 1410 columns]

# %%
df_bsc = df_YA_TVL[df_YA_TVL['Chain'] == 'bsc']
df_eth = df_YA_TVL[df_YA_TVL['Chain'] == 'ethereum']
df_pol = df_YA_TVL[df_YA_TVL['Chain'] == 'polygon']

# %%
df_time = pd.DataFrame(df.loc[0])

# %%
bsc = pd.concat([df_time.T, df_bsc])
bsc_buffer = bsc.drop(columns = ['Unnamed: 0','Category','Chain','Category.1','Token'])
bsc_buffer = bsc_buffer.transpose()
bsc_buffer['date'] = pd.to_datetime(bsc_buffer.loc[:,0])
bsc_buffer = bsc_buffer.drop(bsc_buffer.columns[[0]], axis=1)
bsc_buffer = bsc_buffer.set_index('date')
bsc_buffer = bsc_buffer.fillna(0)
bsc_TVL = bsc_buffer.sum(axis = 1, skipna = True)

# %%
eth = pd.concat([df_time.T, df_eth])
eth_buffer = eth.drop(columns = ['Unnamed: 0','Category','Chain','Category.1','Token'])
eth_buffer = eth_buffer.transpose()
eth_buffer['date'] = pd.to_datetime(eth_buffer.loc[:,0])
eth_buffer = eth_buffer.drop(eth_buffer.columns[[0]], axis=1)
eth_buffer = eth_buffer.set_index('date')
eth_buffer = eth_buffer.fillna(0)
eth_TVL = eth_buffer.sum(axis = 1, skipna = True)

# %%
pol = pd.concat([df_time.T, df_pol])
pol_buffer = pol.drop(columns = ['Unnamed: 0','Category','Chain','Category.1','Token'])
pol_buffer = pol_buffer.transpose()
save_for_later = pol_buffer.loc[:,0]
pol_buffer['date'] = pd.to_datetime(pol_buffer.loc[:,0])
pol_buffer = pol_buffer.drop(pol_buffer.columns[[0]], axis=1)
pol_buffer = pol_buffer.set_index('date')
pol_buffer = pol_buffer.fillna(0)
pol_TVL = pol_buffer.sum(axis = 1, skipna = True)

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'bsc', 'ethereum', 'polygon'
sizes = [bsc_TVL[-1], eth_TVL[-1], pol_TVL[-1]]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
labels = save_for_later
fig, ax = plt.subplots()

ax.bar(labels, eth_TVL, label='eth')
ax.bar(labels, bsc_TVL, bottom=eth_TVL, label='bsc')
ax.bar(labels, pol_TVL, bottom=eth_TVL+bsc_TVL, label='pol')



# ax.set_ylabel('Scores')
# ax.set_title('Scores by group and gender')
ax.legend()

plt.show()
